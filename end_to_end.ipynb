# %%
# !pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image

def resize_image(image_path, new_width, new_height):
    # Carga la imagen
    img = Image.open(image_path)

    # Cambia el tamaño de la imagen
    img_resized = img.resize((new_width, new_height))

    # Muestra la imagen redimensionada
    img_resized.show()

# %% [markdown]
# Topics:
# Representation learning
#
# Un algoritmo basado en representation learning es autoencoder, en el deep learning la representación de las features es muy importante
#
# <div>
# <img src="attachment:1cf57e2a-830c-415d-95e3-57a22666fcd7.png" width="500"/>
# </div>

# %% [markdown]
# A medida que cada capa va un paso mas arriba identifica mas características en la imagen <div>
# <img src="attachment:37e6ccfd-860e-4f45-9691-eab1c95e9927.png" width="500"/>
# </div>

# %% [markdown]
# La mayor diferencia entre los distintos tipos de algoritmos es la siguiente
# <img src="attachment:2f7177ec-40e3-4d5c-88f6-8c74e804a911.png" width="500"/>

# %% [markdown]
# Tipos de redes neuronales y soluciones  ![image.png](attachment:a413c719-4ff7-42c5-a2e8-68a82af004fb.png)
